# %% [markdown]
# # Student Performance in Secondary School

# %% [markdown]
# ## Objective: Train a linear regression model to predict students' final grade given other features and perform necessary evaluations to check the model performance
